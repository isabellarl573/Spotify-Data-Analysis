# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
#pip install nltk
import nltk
nltk.download()
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
#data for Argentina
argentina = pd.read_csv('/Users/timrup/Desktop/Argentina_Top_50.csv')
arg_df = pd.DataFrame(argentina)
arg_popular = arg_df[['name', 'artist', 'popularity']].head(10)
arg_popular = arg_popular.sort_values('popularity', ascending=False).head(10)
arg_danceability = arg_df['danceability']
arg_energy = arg_df['energy']
arg_liveness = arg_df['liveness']
arg_dance = (arg_danceability + arg_energy + arg_liveness) / 3
data_arg = {'name' : arg_df['name'],
     'artist' : arg_df['artist'],
     'dance' : arg_dance,
     }
dance_arg = pd.DataFrame(data_arg)
dance_arg = dance_arg.sort_values('dance', ascending=False).head(50)

# %%
#data for Mexico
Mexico = pd.read_csv('/Users/timrup/Downloads/Mexico_Top_50.csv')
mex_df = pd.DataFrame(Mexico)
mex_popular = mex_df[['name', 'artist', 'popularity']].head(10)
mex_popular = mex_popular.sort_values('popularity', ascending=False).head(10)
mex_danceability = mex_df['danceability']
mex_energy = mex_df['energy']
mex_liveness = mex_df['liveness']
mex_dance = (mex_danceability + mex_energy + mex_liveness) / 3
data_mex = {'name' : mex_df['name'],
     'artist' : mex_df['artist'],
     'dance' : mex_dance,
     }
dance_mex = pd.DataFrame(data_mex)
dance_mex = dance_mex.sort_values('dance', ascending=False).head(50)

# %%
#data for Spain
Spain = pd.read_csv('/Users/timrup/Downloads/Spain_Top_50.csv')
spain_df = pd.DataFrame(Spain)
spain_popular = spain_df[['name', 'artist', 'popularity']].head(10)
spain_popular = spain_popular.sort_values('popularity', ascending=False).head(10)
spain_danceability = spain_df['danceability']
spain_energy = spain_df['energy']
spain_liveness = spain_df['liveness']
spain_dance = (spain_danceability + spain_energy + spain_liveness) / 3
data_spain = {'name' : spain_df['name'],
     'artist' : spain_df['artist'],
     'dance' : spain_dance,
     }
dance_spain = pd.DataFrame(data_spain)
dance_spain = dance_spain.sort_values('dance', ascending=False).head(50)

# %%
#data for South Korea
South_Korea = pd.read_csv('/Users/timrup/Downloads/South Korea_Top_50.csv')
sk_df = pd.DataFrame(South_Korea)
sk_popular = sk_df[['name', 'artist', 'popularity']].head(10)
sk_popular = sk_popular.sort_values('popularity', ascending=False).head(10)
sk_danceability = sk_df['danceability']
sk_energy = sk_df['energy']
sk_liveness = sk_df['liveness']
sk_dance = (sk_danceability + sk_energy + sk_liveness) / 3
data_sk = {'name' : sk_df['name'],
     'artist' : sk_df['artist'],
     'dance' : sk_dance,
     }
dance_sk = pd.DataFrame(data_sk)
dance_sk = dance_sk.sort_values('dance', ascending=False).head(50)

# %%
#data for Japan
Japan = pd.read_csv('/Users/timrup/Downloads/Japan_Top_50.csv')
jap_df = pd.DataFrame(Japan)
jap_popular = jap_df[['name', 'artist', 'popularity']].head(10)
jap_popular = jap_popular.sort_values('popularity', ascending=False).head(10)
jap_danceability = jap_df['danceability']
jap_energy = jap_df['energy']
jap_liveness = jap_df['liveness']
jap_dance = (jap_danceability + jap_energy + jap_liveness) / 3
data_jap = {'name' : jap_df['name'],
     'artist' : jap_df['artist'],
     'dance' : jap_dance,
     }
dance_jap = pd.DataFrame(data_jap)
dance_jap = dance_jap.sort_values('dance', ascending=False).head(50)

# %%
#data for Brazil
Brazil = pd.read_csv('/Users/timrup/Downloads/Brazil_Top_50.csv')
braz_df = pd.DataFrame(Brazil)
braz_popular = braz_df[['name', 'artist', 'popularity']].head(10)
braz_popular = braz_popular.sort_values('popularity', ascending=False).head(10)
braz_danceability = braz_df['danceability']
braz_energy = braz_df['energy']
braz_liveness = braz_df['liveness']
braz_dance = (braz_danceability + braz_energy + braz_liveness) / 3
data_braz = {'name' : braz_df['name'],
     'artist' : braz_df['artist'],
     'dance' : braz_dance,
     }
dance_braz = pd.DataFrame(data_braz)
dance_braz = dance_braz.sort_values('dance', ascending=False).head(50)

# %%
#data for France
France = pd.read_csv('/Users/timrup/Downloads/France_Top_50.csv')
fran_df = pd.DataFrame(France)
fran_popular = fran_df[['name', 'artist', 'popularity']].head(10)
fran_popular = fran_popular.sort_values('popularity', ascending=False).head(10)
fran_danceability = fran_df['danceability']
fran_energy = fran_df['energy']
fran_liveness = fran_df['liveness']
fran_dance = (fran_danceability + fran_energy + fran_liveness) / 3
data_fran = {'name' : fran_df['name'],
     'artist' : fran_df['artist'],
     'dance' : fran_dance,
     }
dance_fran = pd.DataFrame(data_fran)
dance_fran = dance_fran.sort_values('dance', ascending=False).head(50)

# %%
#data for Philippines
Philippines = pd.read_csv('/Users/timrup/Downloads/Philippines_Top_50.csv')
phil_df = pd.DataFrame(Philippines)
phil_popular = phil_df[['name', 'artist', 'popularity']].head(10)
phil_popular = phil_popular.sort_values('popularity', ascending=False).head(10)
phil_danceability = phil_df['danceability']
phil_energy = phil_df['energy']
phil_liveness = phil_df['liveness']
phil_dance = (phil_danceability + phil_energy + phil_liveness) / 3
data_phil = {'name' : phil_df['name'],
     'artist' : phil_df['artist'],
     'dance' : phil_dance,
     }
dance_phil = pd.DataFrame(data_phil)
dance_phil = dance_phil.sort_values('dance', ascending=False).head(50)

# %%
#data for USA
usa = pd.read_csv('/Users/timrup/Downloads/USA_Top_50.csv')
usa_df = pd.DataFrame(usa)
usa_popular = usa_df[['name', 'artist', 'popularity']]
usa_popular = usa_popular.sort_values('popularity', ascending=False).head(10)
usa_danceability = usa_df['danceability']
usa_energy = usa_df['energy']
usa_liveness = usa_df['liveness']
usa_dance = (usa_danceability + usa_energy + usa_liveness) / 3
data_usa = {'name' : usa_df['name'],
     'artist' : usa_df['artist'],
     'dance' : usa_dance,
     }
dance_usa = pd.DataFrame(data_usa)
dance_usa = dance_usa.sort_values('dance', ascending=False).head(50)

# %%
argentina_sorted = arg_popular.sort_values('popularity', ascending=False).head(50)
argentina_sorted
# Out:
#                                            name         artist  popularity
# 0                                    La Bachata  Manuel Turizo          97
# 3         Quevedo: Bzrp Music Sessions, Vol. 52       Bizarrap          97
# 9                                       Hey Mor          Ozuna          90
# 5                                       Punto G        Quevedo          88
# 7                                      DESPECHÁ        ROSALÍA          86
# 4                                    Tu Turrito            Rei          82
# 2                              CÓMO CHILLA ELLA          YSY A          81
# 6                                      Butakera      La Joaqui          81
# 1                                   Dos Besitos      La Joaqui          80
# 8  CALLEJERO FINO | DJ TAO Turreo Sessions #723         DJ Tao          76

# %%
#search query for spotify data on 9 countries
def process_query(query):
  #Tokenize the query and remove stop words
  query_tokens = word_tokenize(query)
  query_tokens = [token for token in query_tokens if token not in stopwords.words("english")]
  

  keywords = []
  #find keywords in input 
  for token in query_tokens:
    if token in ["songs", "popular", "argentina"]:
           keywords.append(token)
    if token in ["songs", "dance", "argentina"]:
           keywords.append(token)
    if token in ["songs", "popular", "mexico"]:
           keywords.append(token)
    if token in ["songs", "dance", "mexico"]:
           keywords.append(token)     
    if token in ["songs", "popular", "spain"]:
           keywords.append(token)
    if token in ["songs", "dance", "spain"]:
           keywords.append(token)     
    if token in ["songs", "popular", "south korea"]:
           keywords.append(token)
    if token in ["songs", "dance", "south korea"]:
           keywords.append(token)              
    if token in ["songs", "popular", "japan"]:
           keywords.append(token)
    if token in ["songs", "dance", "japan"]:     
           keywords.append(token)
    if token in ["songs", "popular", "france"]:
           keywords.append(token)
    if token in ["songs", "dance", "france"]:     
           keywords.append(token)           
    if token in ["songs", "popular", "brazil"]:
           keywords.append(token)
    if token in ["songs", "dance", "brazil"]:     
           keywords.append(token)
    if token in ["songs", "popular", "philippines"]:
           keywords.append(token)
    if token in ["songs", "dance", "philippines"]:     
           keywords.append(token)
    if token in ["songs", "popular", "usa"]:
           keywords.append(token)
    if token in ["songs", "dance", "usa"]:     
           keywords.append(token)          

  # return results based on keywords. user can search for the songs with the most popularity or 
  # a number of the best dance songs (<50) in any of the nine countries
  # ex: "top 10 dance songs in spain"  
  # ex: "most popular songs in france"                                                 
  if "songs" in keywords and "popular" in keywords and "argentina" in keywords:
    popular_songs = argentina_sorted
    return popular_songs
  if "songs" in keywords and "dance" in keywords and "argentina" in keywords:
    dance_songs = dance_arg.head(res)
    return dance_songs
  if "songs" in keywords and "popular" in keywords and "mexico" in keywords:
    popular_songs = mex_popular
    return popular_songs
  if "songs" in keywords and "dance" in keywords and "mexico" in keywords:
    dance_songs = dance_mex.head(res)
    return dance_songs    
  if "songs" in keywords and "popular" in keywords and "spain" in keywords:

    popular_songs = spain_popular
    return popular_songs
  if "songs" in keywords and "dance" in keywords and "spain" in keywords:
    dance_songs = dance_spain.head(res)
    return dance_songs     
  if "songs" in keywords and "popular" in keywords and "south korea" in keywords:
   
    popular_songs = sk_popular
    return popular_songs
  if "songs" in keywords and "dance" in keywords and "south korea" in keywords:
    dance_songs = dance_sk.head(res)
    return dance_songs
  if "songs" in keywords and "popular" in keywords and "japan" in keywords:
    popular_songs = jap_popular
    return popular_songs
  if "songs" in keywords and "dance" in keywords and "japan" in keywords:
    dance_songs = dance_jap.head(res)
    return dance_songs    
  if "songs" in keywords and "popular" in keywords and "france" in keywords:
    popular_songs = fran_popular
    return popular_songs
  if "songs" in keywords and "dance" in keywords and "france" in keywords:
    dance_songs = dance_fran.head(res)
    return dance_songs 
  if "songs" in keywords and "popular" in keywords and "brazil" in keywords:
    popular_songs = braz_popular
    return popular_songs
  if "songs" in keywords and "dance" in keywords and "brazil" in keywords:
    dance_songs = dance_braz.head(res)
    return dance_songs    
  if "songs" in keywords and "popular" in keywords and "philippines" in keywords:
    popular_songs = phil_popular
    return popular_songs
  if "songs" in keywords and "dance" in keywords and "philippines" in keywords:
    dance_songs = dance_phil.head(res)
    return dance_songs     
  if "songs" in keywords and "popular" in keywords and "usa" in keywords:
    popular_songs = usa_popular
    return popular_songs
  if "songs" in keywords and "dance" in keywords and "usa" in keywords:
    dance_songs = dance_usa.head((res))
    return dance_songs          
  else:
    return "Sorry, I couldn't understand your query. Please try again."


#user input
a = input()
query = a
#look for number 
num = [int(i) for i in query.split() if i.isdigit()]
if num:
  res = num[0]
results = process_query(query)
print(results)
# Out:
#                         name          artist     dance
# 34                 Good Days             SZA  0.631333
# 10  Used (feat. Don Toliver)             SZA  0.583667
# 30             Feliz Navidad  José Feliciano  0.543667
